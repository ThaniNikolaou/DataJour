# %%
import pandas as pd
# %matplotlib inline
import numpy as np
import glob
from sklearn.feature_extraction.text import CountVectorizer
from datetime import datetime
from google.colab import drive
drive.mount('/content/gdrive')
import spacy
# Out:
# Mounted at /content/gdrive

# %%
voice_full_df= pd.read_csv ('/content/gdrive/MyDrive/DATA_JOUR/FINAL ESSAY/voice_full_df.csv')

# %%
efsyn_full_articles_df = pd.read_csv ('/content/gdrive/MyDrive/DATA_JOUR/FINAL ESSAY/efsyn_full.csv')

# %%
bomb_full_articles_df= pd.read_csv('/content/gdrive/MyDrive/DATA_JOUR/FINAL ESSAY/bomb_full_df.csv')

# %%
news_full_articles_df= pd.read_csv('/content/gdrive/MyDrive/DATA_JOUR/FINAL ESSAY/news_full.csv')

# %%
beast_full_df= pd.read_csv('/content/gdrive/MyDrive/DATA_JOUR/FINAL ESSAY/beast_full_df.csv')

# %% [markdown]
# **ATHENS VOICE**

# %%
graph_voice_df = voice_full_df [['datetime', 'full_text']]

# %%
graph_voice_df['year'] = pd.DatetimeIndex(graph_voice_df['datetime']).year
graph_voice_df['month'] = pd.DatetimeIndex(graph_voice_df['datetime']).month
graph_voice_df['day'] = pd.DatetimeIndex(graph_voice_df['datetime']).day
graph_voice_df['hour'] = pd.DatetimeIndex(graph_voice_df['datetime']).hour

# %%
graph_voice_df['day']. value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# **EFSYN**

# %%
graph_efsyn_df = efsyn_full_articles_df [['datetime', 'full_text']]

# %%
efsyn_full_articles_df.dtypes

# %%
graph_efsyn_df['day']. value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# **NEWSBOMB**

# %%
graph_bomb_df = bomb_full_articles_df[['datetime', 'full_text']]

# %%
graph_bomb_df['year'] = pd.DatetimeIndex(graph_bomb_df['datetime']).year
graph_bomb_df['month'] = pd.DatetimeIndex(graph_bomb_df['datetime']).month
graph_bomb_df['day'] = pd.DatetimeIndex(graph_bomb_df['datetime']).day
graph_bomb_df['hour'] = pd.DatetimeIndex(graph_bomb_df['datetime']).hour

# %%
graph_bomb_df['day']. value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# **NEWS.GR**

# %%
graph_news_df = news_full_articles_df[['datetime', 'full_text']]

# %%
graph_news_df['year'] = pd.DatetimeIndex(graph_news_df['datetime']).year
graph_news_df['month'] = pd.DatetimeIndex(graph_news_df['datetime']).month
graph_news_df['day'] = pd.DatetimeIndex(graph_news_df['datetime']).day
graph_news_df['hour'] = pd.DatetimeIndex(graph_news_df['datetime']).hour

# %%
graph_news_df['day']. value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# **NEWSBEAST**

# %%
graph_beast_df = beast_full_df[['datetime', 'full_text']]

# %%
graph_beast_df['year'] = pd.DatetimeIndex(graph_beast_df['datetime']).year
graph_beast_df['month'] = pd.DatetimeIndex(graph_beast_df['datetime']).month
graph_beast_df['day'] = pd.DatetimeIndex(graph_beast_df['datetime']).day
graph_beast_df['hour'] = pd.DatetimeIndex(graph_beast_df['datetime']).hour

# %%
graph_beast_df['day']. value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %%
combined_df = pd.concat([voice_full_df, efsyn_full_articles_df, bomb_full_articles_df, news_full_articles_df, beast_full_df], ignore_index=True)

# %%
import matplotlib.pyplot as plt

month_counts = combined_df['month'].value_counts()

plt.pie(month_counts, labels=month_counts.index, autopct='%1.1f%%')

plt.title('Διανομή των άρθρων ανά μήνα')

plt.show()
