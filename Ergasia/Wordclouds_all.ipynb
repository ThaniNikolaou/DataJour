# %%
import pandas as pd
# %matplotlib inline
import numpy as np
import glob
from sklearn.feature_extraction.text import CountVectorizer
from datetime import datetime
from google.colab import drive
drive.mount('/content/gdrive')
import spacy
# Out:
# Mounted at /content/gdrive

# %%
# !python -m spacy download el_core_news_sm

# %%
nlp = spacy.load('el_core_news_sm')

# %%
voice_full_df= pd.read_csv ('/content/gdrive/MyDrive/DATA_JOUR/FINAL ESSAY/voice_full_df.csv')
efsyn_full_articles_df = pd.read_csv ('/content/gdrive/MyDrive/DATA_JOUR/FINAL ESSAY/efsyn_full.csv')
bomb_full_articles_df= pd.read_csv('/content/gdrive/MyDrive/DATA_JOUR/FINAL ESSAY/bomb_full_df.csv')
news_full_articles_df= pd.read_csv('/content/gdrive/MyDrive/DATA_JOUR/FINAL ESSAY/news_full.csv')
beast_full_df= pd.read_csv('/content/gdrive/MyDrive/DATA_JOUR/FINAL ESSAY/beast_full_df.csv')

# %% [markdown]
# **ATHENSVOICE**

# %%
word_voice_df = voice_full_df [['datetime', 'full_text']]

# %%
word_voice_df['year'] = pd.DatetimeIndex(word_voice_df['datetime']).year
word_voice_df['month'] = pd.DatetimeIndex(word_voice_df['datetime']).month
word_voice_df['day'] = pd.DatetimeIndex(word_voice_df['datetime']).day
word_voice_df['hour'] = pd.DatetimeIndex(word_voice_df['datetime']).hour

# %%
word_voice_df[word_voice_df['day']==30]['full_text']

# %%
text = word_voice_df[word_voice_df['day']==30]['full_text'].str.cat(sep = ' ')
text

# %%
doc = nlp(word_voice_df['full_text'][1])
for token in doc:
    print(token, token.lemma_)
' '.join(token.lemma_ for token in doc)

# %%
text

# %%
full_doc = nlp(text)

# %%
clear_text = ' '.join(token.lemma_ for token in full_doc)

# %%
wordcloud = WordCloud(
    stopwords = nlp.Defaults.stop_words,
    width = 2000,
    height = 1000,
    background_color = 'white'
 ).generate(clear_text)
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'kaiser')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# **EFSYN**

# %%
word_efsyn_df = efsyn_full_articles_df [['datetime', 'full_text']]

# %%
word_efsyn_df['year'] = pd.DatetimeIndex(word_efsyn_df['datetime']).year
word_efsyn_df['month'] = pd.DatetimeIndex(word_efsyn_df['datetime']).month
word_efsyn_df['day'] = pd.DatetimeIndex(word_efsyn_df['datetime']).day
word_efsyn_df['hour'] = pd.DatetimeIndex(word_efsyn_df['datetime']).hour

# %%
word_efsyn_df[word_efsyn_df['day']==30]['full_text']

# %%
text = word_efsyn_df[word_efsyn_df['day']==30]['full_text'].str.cat(sep = ' ')
text

# %%
doc = nlp(word_efsyn_df['full_text'][1])
for token in doc:
    print(token, token.lemma_)
' '.join(token.lemma_ for token in doc)

# %%
text

# %%
full_doc = nlp(text)

# %%
clear_text = ' '.join(token.lemma_ for token in full_doc)

# %%
wordcloud = WordCloud(
    stopwords = nlp.Defaults.stop_words,
    width = 2000,
    height = 1000,
    background_color = 'white'
 ).generate(clear_text)
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'kaiser')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# **NEWSBOMB**

# %%
word_bomb_df = bomb_full_articles_df [['datetime', 'clean_text']]

# %%
word_bomb_df['year'] = pd.DatetimeIndex(word_bomb_df['datetime']).year
word_bomb_df['month'] = pd.DatetimeIndex(word_bomb_df['datetime']).month
word_bomb_df['day'] = pd.DatetimeIndex(word_bomb_df['datetime']).day
word_bomb_df['hour'] = pd.DatetimeIndex(word_bomb_df['datetime']).hour

# %%
word_bomb_df[word_bomb_df['day']==30]['clean_text']

# %%
text = word_bomb_df[word_bomb_df['day']==30]['clean_text'].str.cat(sep = ' ')
text

# %%
doc = nlp(word_bomb_df['clean_text'][1])
for token in doc:
    print(token, token.lemma_)
' '.join(token.lemma_ for token in doc)

# %%
text

# %%
full_doc = nlp(text)

# %%
clear_text = ' '.join(token.lemma_ for token in full_doc)

# %%
wordcloud = WordCloud(
    stopwords = nlp.Defaults.stop_words,
    width = 2000,
    height = 1000,
    background_color = 'white'
 ).generate(clear_text)
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'kaiser')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# **NEWS.GR**

# %%
news_full_articles_df['clean_text'] = news_full_articles_df['full_text'].str.replace("News.gr", "").str.replace("Copyright News", "")
# Out:
# <ipython-input-87-1932a196f152>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   news_full_articles_df['clean_text'] = news_full_articles_df['full_text'].str.replace("News.gr", "").str.replace("Copyright News", "")

# %%
word_news_df = news_full_articles_df [['datetime', 'clean_text']]

# %%
word_news_df['year'] = pd.DatetimeIndex(word_news_df['datetime']).year
word_news_df['month'] = pd.DatetimeIndex(word_news_df['datetime']).month
word_news_df['day'] = pd.DatetimeIndex(word_news_df['datetime']).day
word_news_df['hour'] = pd.DatetimeIndex(word_news_df['datetime']).hour

# %%
word_news_df[word_news_df['day']==30]['clean_text']

# %%
text = word_news_df[word_news_df['day']==30]['clean_text'].str.cat(sep = ' ')
text

# %%
doc = nlp(word_news_df['clean_text'][1])
for token in doc:
    print(token, token.lemma_)
' '.join(token.lemma_ for token in doc)

# %%
text

# %%
full_doc = nlp(text)

# %%
clear_text = ' '.join(token.lemma_ for token in full_doc)

# %%
wordcloud = WordCloud(
    stopwords = nlp.Defaults.stop_words,
    width = 2000,
    height = 1000,
    background_color = 'white'
 ).generate(clear_text)
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'kaiser')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# **NEWSBEAST**

# %%
word_beast_df = beast_full_df [['datetime', 'full_text']]

# %%
word_beast_df['year'] = pd.DatetimeIndex(word_beast_df['datetime']).year
word_beast_df['month'] = pd.DatetimeIndex(word_beast_df['datetime']).month
word_beast_df['day'] = pd.DatetimeIndex(word_beast_df['datetime']).day
word_beast_df['hour'] = pd.DatetimeIndex(word_beast_df['datetime']).hour

# %%
word_beast_df[word_beast_df['day']==29]['full_text']

# %%
text = word_beast_df[word_beast_df['day']==29]['full_text'].str.cat(sep = ' ')
text

# %%
doc = nlp(word_beast_df['full_text'][1])
for token in doc:
    print(token, token.lemma_)
' '.join(token.lemma_ for token in doc)

# %%
text

# %%
full_doc = nlp(text)

# %%
clear_text = ' '.join(token.lemma_ for token in full_doc)

# %%
wordcloud = WordCloud(
    stopwords = nlp.Defaults.stop_words,
    width = 2000,
    height = 1000,
    background_color = 'white'
 ).generate(clear_text)
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'kaiser')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
